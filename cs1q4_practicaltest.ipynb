# %% [markdown]
# <a href="https://colab.research.google.com/github/IMKOOLAID4/cs1q4_practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name?: ")
amount = input("How many quiz scores do you want to input?: ")
scores = input ("What is your score?: ")

for score in range (amount):
  scores = input ("What is your score?: ")
  print (scores)





# determine if pass or fail
if avarage >= 75 :
  (print("Passing"))
else :
  print ("Fail")

  def avarage (score):
   return  (score) /2

print(avarage (scores))
# Out:
# What is your name?: T
